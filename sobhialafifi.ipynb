# %%
@Rule(
    Fact(stimulus_situation='verbal'),
    Fact(stimulus_response='oral'),
    Feedback(feedback='required'),
    salience=10
)
def lecture_tutorial(self):
    self.declare(Medium(medium='lecture – tutorial'))


@Rule(
    Fact(stimulus_situation='verbal'),
    Fact(stimulus_response='oral'),
    Feedback(feedback='required'),
    salience=5
)
def role_play(self):
    self.declare(Medium(medium='role-play exercises'))
